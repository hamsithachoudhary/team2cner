-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082007000400010-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0376-78922007000400008-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1137-66272008000500007-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0210-48062009000600016-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0211-69952016000600552-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0212-71992004000300009-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/S0004-06142006000100014-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082004001200010-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-63432014000500008-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0365-66912008000700010-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1139-76322013000200009-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1139-76322009000700016-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1698-69462006000100006-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1887-85712016000100005-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0365-66912009000300009-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1139-76322014000100006-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0212-16112011000300031-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1699-695X2015000300013-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082008001000010-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0210-48062007000100011-1.ann
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1139-76322016000400018-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1699-65852007000300003-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082008000500008-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082007001200014-1.ann
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082005001100016-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-05582015000100008-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1137-66272016000200014-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1134-80462005000300004-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082007001100009-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0365-66912007000200011-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0212-71992000001200010-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1138-123X2005000200006-2.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0376-78922014000100013-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0365-66912004000800009-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1887-85712012000400006-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0210-56912010000200009-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1698-44472004000100009-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1137-66272013000200022-1.ann
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0004-06142007000900010-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1137-66272016000300010-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082007000300006-7.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-05582017000300150-3.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0365-66912007001200009-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0210-48062006000700012-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-63432014000600009-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/S0004-06142007000300012-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082009000700012-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0210-56912008000200007-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0365-66912005001100010-2.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0210-48062007000700016-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0365-66912010000700004-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-05582007000500007-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1139-76322016000300013-1.ann
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0365-66912004000900009-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0365-66912006001100006-4.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1139-76322015000500009-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1889-836X2015000200005-2.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0210-48062007001000004-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0210-56912009000800006-3.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0365-66912006001000011-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0211-69952015000600014-2.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0365-66912007001100010-1.ann
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1137-66272012000300024-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0378-48352006000300005-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1139-13752009000200010-2.ann
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082009000300015-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1139-76322015000300013-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1134-80462009000100005-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0210-48062005000400012-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0212-71992005000600008-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082006000700014-1.ann
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0210-48062009000600012-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0210-48062006000400012-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1135-76062009000300004-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0212-71992005000400007-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0212-71992000001200009-1.ann
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082010000400015-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0376-78922009000400002-2.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082010000600013-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1698-44472004000500007-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1134-80462015000500005-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082010001100014-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082007000700011-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0210-56912008000400007-3.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0004-06142008000500015-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1137-66272016000200010-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1137-66272014000200013-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0376-78922015000400012-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082008000200010-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-14732006000400005-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0365-66912006000700009-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1139-76322010000300008-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082008001000008-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1134-80462013000400006-2.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0212-71992005001100007-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0004-06142008000500009-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0211-69952017000200225-2.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082009000500007-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0212-16112004000400007-1.ann
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0212-16112007000100015-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0376-78922012000400009-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082005000800013-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0365-66912007000700009-1.ann
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0211-69952016000200176-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082009000500013-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1137-66272007000500016-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0212-71992000001200006-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0365-66912004001100012-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-14732005000200009-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0376-78922016000300005-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1139-76322016000300008-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/S0004-06142005000700014-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0212-16112014000300032-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1889-836X2015000400006-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0210-48062005000700012-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0365-66912007000100010-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1134-80462014000300009-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0376-78922007000300006-3.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S1130-01082009000600013-1.txt
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0378-48352005000700007-2.ann
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/brat/es-S0004-06142007000700015-1.ann
#    creating: multicardioner_train+dev_240429/track2/drugtemist_train/it/tsv/
#   inflating: multicardioner_train+dev_240429/track2/drugtemist_train/it/tsv/multicardioner_track2_drugtemist_train_it.tsv
#   inflating: multicardioner_train+dev_240429/README.md
#   inflating: multicardioner_train+dev_240429/LICENSE

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from gensim.models import FastText
from gensim.utils import simple_preprocess

# %%
# Function to read text from a file
def read_text_file(file_path):
    with open(file_path, 'r') as file:
        return file.read()

# Function to read annotations from a file
def read_annotations_file(file_path):
    annotations = {}
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.strip().split('\t')
            if len(parts) >= 4:
                _, _, start, end, word = parts[:5]
                for i in range(int(start), int(end)):
                    annotations[i] = "FARMACO"  # Store word indices with entity type "FARMACO"
    return annotations

# %%
# Define BiLSTM model
class BiLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(BiLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.lstm = nn.LSTM(input_size, hidden_size, bidirectional=True)
        self.fc = nn.Linear(hidden_size * 2, output_size)  # *2 for bidirectional

    def forward(self, input):
        lstm_out, _ = self.lstm(input)
        output = self.fc(lstm_out)
        return output

# %%
train_folder_path = "/content/multicardioner_train+dev_240429/track2/cardioccc_dev/en/brat"

# %%
# Function to process text files and generate word embeddings
def process_text_files(folder_path):
    all_words = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".txt"):
            # Get corresponding annotation file
            annotation_file_name = file_name.replace(".txt", ".ann")
            annotation_file_path = os.path.join(folder_path, annotation_file_name)

            # Read text from the text file
            text = read_text_file(os.path.join(folder_path, file_name))
            # Tokenize the text and add words to the list
            all_words.extend(simple_preprocess(text))

            # Read annotations from the annotation file
            annotations = read_annotations_file(annotation_file_path)

    # Train FastText model
    model = FastText(sentences=[all_words], vector_size=100, window=5, min_count=1, workers=4)

    # Create word-to-index mapping
    word_to_ix = {word: idx for idx, word in enumerate(model.wv.index_to_key)}

    # Generate ground truth annotation list
    ground_truth_annotations = []
    for idx, word in enumerate(all_words):
        if idx in annotations:
            ground_truth_annotations.append((idx, annotations[idx]))
        else:
            ground_truth_annotations.append((idx, "O"))  # Assign "O" tag to non-entity words

    # Convert word embeddings and annotations to PyTorch tensors
    word_embeddings_tensor = torch.tensor(model.wv[model.wv.index_to_key])
    annotations_tensor = torch.tensor([1 if anno[1] == "FARMACO" else 0 for anno in ground_truth_annotations])

    return word_embeddings_tensor, annotations_tensor, word_to_ix

# %%
# Function to train BiLSTM model
def train_bilstm_model(word_embeddings_tensor, annotations_tensor, word_to_ix):
    # Define hyperparameters
    input_size = word_embeddings_tensor.size(1)  # Embedding dimension
    hidden_size = 128
    output_size = 2  # Binary classification: FARMACO or not

    # Instantiate BiLSTM model
    model = BiLSTM(input_size, hidden_size, output_size)

    # Define loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    # Training loop
    num_epochs = 10
    batch_size = 32
    num_batches = len(word_embeddings_tensor) // batch_size

    for epoch in range(num_epochs):
        total_loss = 0
        for i in range(num_batches):
            model.train()
            optimizer.zero_grad()

            # Get current batch
            batch_embeddings = word_embeddings_tensor[i*batch_size:(i+1)*batch_size]
            batch_annotations = annotations_tensor[i*batch_size:(i+1)*batch_size]

            # Forward pass
            outputs = model(batch_embeddings)

            # Calculate loss
            loss = criterion(outputs.view(-1, output_size), batch_annotations)
            total_loss += loss.item()

            # Backward pass and optimization
            loss.backward()
            optimizer.step()

        print('Epoch [{}/{}], Loss: {:.4f}'.format(epoch+1, num_epochs, total_loss / num_batches))

# %%
# Main function
def main():
    word_embeddings_tensor, annotations_tensor, word_to_ix = process_text_files(train_folder_path)
    train_bilstm_model(word_embeddings_tensor, annotations_tensor, word_to_ix)

# %%
if __name__ == "__main__":
    main()
# Out:
# Epoch [1/10], Loss: 0.0158
# Epoch [2/10], Loss: 0.0000
# Epoch [3/10], Loss: 0.0000
# Epoch [4/10], Loss: 0.0000
# Epoch [5/10], Loss: 0.0000
# Epoch [6/10], Loss: 0.0000
# Epoch [7/10], Loss: 0.0000
# Epoch [8/10], Loss: 0.0000
# Epoch [9/10], Loss: 0.0000
# Epoch [10/10], Loss: 0.0000
